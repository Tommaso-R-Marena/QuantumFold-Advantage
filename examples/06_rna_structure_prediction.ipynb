# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tommaso-R-Marena/QuantumFold-Advantage/blob/main/examples/06_rna_structure_prediction.ipynb)

# %% [markdown]
# # RNA Structure Prediction
# RNA embeddings and structure prediction workflow.

# %%
import src
print('Notebook scaffold ready')
