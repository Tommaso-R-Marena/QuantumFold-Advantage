# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tommaso-R-Marena/QuantumFold-Advantage/blob/main/examples/09_api_cloud_deployment.ipynb)

# %% [markdown]
# # API + Cloud Deployment
# FastAPI, Celery, and Kubernetes walkthrough.

# %%
import src
print('Notebook scaffold ready')
